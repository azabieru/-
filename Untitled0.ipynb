# %% [markdown]
# <a href="https://colab.research.google.com/github/azabieru/-/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ライブラリインストール
# !pip install easyocr --no-deps # Colab already has all dependencies
! pip install python-bidi
# Out:
# ...
#      |████████████████████████████████| 63.6 MB 68 kB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# easyocr 1.4.1 requires opencv-python-headless, which is not installed.
# ...

# %%
#サンプル画像を使う場合easyocrからDLする
# !npx degit JaidedAI/EasyOCR/examples -f
# Out:
# npx: installed 1 in 3.788s
# > destination directory is not empty. Using --force, continuing
# > cloned JaidedAI/EasyOCR#HEAD

# %%
import PIL
from PIL import ImageDraw
jp_img = "test.png" #分析対象の画像を入れる
im = PIL.Image.open(jp_img)
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=738x309 at 0x7FB05F6F5290>

# %%
#OCRの実行
import easyocr
reader = easyocr.Reader(['ja','en'])
bounds = reader.readtext(jp_img)
bounds
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# [([[39, 1], [81, 1], [81, 39], [39, 39]], '『ニ', 0.3118872531722052),
#  ([[94, 4], [259, 4], [259, 45], [94, 45]], 'を飛びこえてぃく', 0.9127353762316949),
#  ([[286, 0], [661, 0], [661, 37], [286, 37]],
#   '-3X-5=-6X+l@Z-り=3X',
#   0.2885562159096129),
#  ([[27, 37], [248, 37], [248, 76], [27, 76]],
#   '西頭という技を使って',
#   0.06689990328426063),
#  ([[23, 71], [221, 71], [221, 109], [23, 109]],
#   '左辺に@立空_』がを一',
#   0.047890515680671306),
#  ([[22, 99], [231, 99], [231, 138], [22, 138]],
#   '右辺に@数だ心頃を',
#   0.009888951764066423),
#  ([[23, 131], [249, 131], [249, 169], [23, 169]],
#   '集めるあとのを使う',
#   0.25768294113462675),
#  ([[26, 170], [66, 170], [66, 198], [26, 198]], 'と@', 0.9898734559977699),
#  ([[59, 157], [235, 157], [235, 199], [59, 199]],
#   '盤 が変わるよ。',
#   0.11366512242463281),
#  ([[283, 179], [461, 179], [461, 215], [283, 215]],
#   '6+5X=2X+6',
#   0.6713609254354191),
# ...

# %%
# バウンティーボックスの表示
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=738x309 at 0x7F747A8724D0>
